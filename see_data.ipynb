# %%
import pandas as pd

# %%
DATASET_PATH = "./data/movie_dataset.csv"

# %%
movie_df = pd.read_csv(DATASET_PATH)

# %%
movie_df.loc[0, "plot_keywords"].lower().split("|")
# Out:
# ['avatar', 'future', 'marine', 'native', 'paraplegic']

# %%
movie_df
# Out:
#                                     movie_title      director_name  \
# 0                                       Avatar       James Cameron
# 1     Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                      Spectre          Sam Mendes
# 3                        The Dark Knight Rises   Christopher Nolan
# 4                                  John Carter      Andrew Stanton
# ...                                         ...                ...
# 5037                   Signed Sealed Delivered         Scott Smith
# 5038                 The Following                             NaN
# 5039                      A Plague So Pleasant    Benjamin Roberds
# 5040                          Shanghai Calling         Daniel Hsia
# 5041                         My Date with Drew            Jon Gunn
#
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4             Action|Adventure|Sci-Fi
# ...                               ...
# 5037                     Comedy|Drama
# 5038     Crime|Drama|Mystery|Thriller
# 5039            Drama|Horror|Thriller
# 5040             Comedy|Drama|Romance
# 5041                      Documentary
#
#                                           plot_keywords  \
# 0                avatar|future|marine|native|paraplegic
# 1     goddess|marriage ceremony|marriage proposal|pi...
# 2                   bomb|espionage|sequel|spy|terrorist
# 3     deception|imprisonment|lawlessness|police offi...
# 4     alien|american civil war|male nipple|mars|prin...
# ...                                                 ...
# 5037             fraud|postal worker|prison|theft|trial
# 5038       cult|fbi|hideout|prison escape|serial killer
# 5039                                                NaN
# 5040                                                NaN
# 5041  actress name in title|crush|date|four word tit...
#
#                                         movie_imdb_link  title_year  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...      2009.0
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...      2007.0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...      2015.0
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...      2012.0
# 4     http://www.imdb.com/title/tt0401729/?ref_=fn_t...      2012.0
# ...                                                 ...         ...
# 5037  http://www.imdb.com/title/tt3000844/?ref_=fn_t...      2013.0
# 5038  http://www.imdb.com/title/tt2071645/?ref_=fn_t...         NaN
# 5039  http://www.imdb.com/title/tt2107644/?ref_=fn_t...      2013.0
# 5040  http://www.imdb.com/title/tt2070597/?ref_=fn_t...      2012.0
# 5041  http://www.imdb.com/title/tt0378407/?ref_=fn_t...      2004.0
#
#      content_rating
# 0             PG-13
# 1             PG-13
# 2             PG-13
# 3             PG-13
# 4             PG-13
# ...             ...
# 5037            NaN
# 5038          TV-14
# 5039            NaN
# 5040          PG-13
# 5041             PG
#
# [5042 rows x 7 columns]
